# %% [markdown]
# # Model training and testing
#
# In the following notebook we will work with the numpy data generated by the data_processing.ipynb notebook to train and test machine learning models.

# %% [markdown]
# ### First model: ANN in keras, undersampling the majority class for balance
#
# We must start by loading the data stored from the data processing stage, this means both the stars one hot encoding dictionary, as well as the numpy arrays containing the training and test spectrum data and label data.

# %%
# load the one hot encoding dictionary from the pre processing stage

import pickle

with open("stars_encoding.txt", "rb") as myFile:
    stars_encoding = pickle.load(myFile)

print(stars_encoding)

# %%
# now we will load the training and validation set matrices

import numpy as np
from pathlib import Path
import os

project_dir =  Path(globals()['_dh'][0]).parent
    

train_label_matrix = np.load(os.path.join(project_dir, r'data\processed\lpv1_train_label_matrix.npy'))
valid_label_matrix = np.load(os.path.join(project_dir, r'data\processed\lpv1_valid_label_matrix.npy'))
train_spectrum_matrix = np.load(os.path.join(project_dir, r'data\processed\lpv1_train_spectrum_matrix.npy'))
valid_spectrum_matrix = np.load(os.path.join(project_dir, r'data\processed\lpv1_valid_spectrum_matrix.npy'))

# %%
print(train_spectrum_matrix.shape, train_label_matrix.shape, valid_spectrum_matrix.shape, valid_label_matrix.shape)
# Out:
# (3366, 4200) (3366, 12) (1123, 4200) (1123, 12)

# %% [markdown]
# Now, we are still facing the problem of having to train an umbalanced set. There are many strategies which will have to be explored in order to solve this issue. For example:
#
# <ul>
#   <li>We could undersample the biggest dataset, oversample it, or a combination of both. There are also numerous algorithms to do so.</li>
#   <li>We could take advantage of the fact that there are a number of different observations from the same object so as to perform data augmentation using those spectrums, instead of one per object.</li>
#   <li>We could use class weights in the optimization process, as a parameter to the model.fit call.</li>
#   <li>We could perform other data augmentation techniques, like looking for other similarly classified spectra elsewhere, building synthetic spectra, etc.</li>
# </ul>
#
# First, we'll simply undersample the majority class in the trainig set. Code is also available (commented) to try out the class wegiht parameter for model.fit

# %%
# try running pip install imblearn if this line doesn't work.
# Resampling the majority dataset in order to balance the set.

from imblearn.under_sampling import RandomUnderSampler
under_sampler = RandomUnderSampler(random_state=40, sampling_strategy='majority')
X_under, Y_under = under_sampler.fit_resample(train_spectrum_matrix, train_label_matrix)

# %% [markdown]
# We can now see the distribution of the one hot encoded labels

# %%
from collections import Counter

newLabels = Counter()
for label in Y_under:
    for idx, key in enumerate(label):
         newLabels[idx]+=key

print(newLabels)
# Out:
# Counter({2: 327, 5: 215, 4: 201, 6: 135, 1: 80, 11: 70, 0: 67, 10: 55, 7: 31, 8: 10, 3: 6, 9: 6})

# %% [markdown]
# ### ANN training example
#
# Now we can take our resample data (which resampled or in this case, undersampled the majority class) and train our ANN model. This particular ANN structure will have the same hidden layers and acxtivation functions found in Sharma et al, but other parameters may not be the same.

# %%
# Code to inpuit class weights parameter for model.fit

# First we'll define a class weight dictionary
# from sklearn.utils.class_weight import compute_class_weight

# y_integers = np.argmax(train_label_matrix, axis=1)
# class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_integers), y=y_integers)
# d_class_weights = dict(enumerate(class_weights))
# print(d_class_weights)

# %% [markdown]
# We now proceed to define our model, and other relevant parameters for training the ANN using keras. We will train our model using batch sizes of 32 samples (our ANN weights will be updated using batches or chunks of 32 samples) and for 100 epochs (we will go over our training set for a total of 100 times).

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %%
#opt = SGD(lr=0.001)

model = Sequential([Dense(4200, input_dim = 4200, activation='relu', kernel_initializer='uniform'),
                    Dense(32, activation='relu', kernel_initializer='uniform'),
                    Dense(64, activation='relu', kernel_initializer='uniform'),
                    Dense(len(stars_encoding), activation='softmax', kernel_initializer='uniform')])

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
history = model.fit(X_under,Y_under, batch_size=32, epochs=30 , validation_data=(valid_spectrum_matrix, valid_label_matrix))
# Out:
# Epoch 1/30
# 38/38 [==============================] - 4s 104ms/step - loss: 2.3484 - accuracy: 0.4289 - val_loss: 4.6028 - val_accuracy: 0.1781
# Epoch 2/30
# 38/38 [==============================] - 4s 106ms/step - loss: 2.0873 - accuracy: 0.5195 - val_loss: 4.5794 - val_accuracy: 0.1941
# Epoch 3/30
# 38/38 [==============================] - 4s 106ms/step - loss: 1.5708 - accuracy: 0.5603 - val_loss: 5.1249 - val_accuracy: 0.2066
# Epoch 4/30
# 38/38 [==============================] - 4s 105ms/step - loss: 2.2753 - accuracy: 0.5960 - val_loss: 4.3456 - val_accuracy: 0.2244
# Epoch 5/30
# 38/38 [==============================] - 4s 108ms/step - loss: 1.6502 - accuracy: 0.6193 - val_loss: 5.6456 - val_accuracy: 0.2084
# Epoch 6/30
# 38/38 [==============================] - 4s 106ms/step - loss: 1.1852 - accuracy: 0.6426 - val_loss: 5.1711 - val_accuracy: 0.2191
# Epoch 7/30
# 38/38 [==============================] - 4s 107ms/step - loss: 2.1954 - accuracy: 0.6592 - val_loss: 4.8029 - val_accuracy: 0.2244
# Epoch 8/30
# 38/38 [==============================] - 4s 106ms/step - loss: 1.2353 - accuracy: 0.6509 - val_loss: 4.8332 - val_accuracy: 0.2413
# Epoch 9/30
# 38/38 [==============================] - 4s 109ms/step - loss: 1.1635 - accuracy: 0.6517 - val_loss: 4.6044 - val_accuracy: 0.2449
# Epoch 10/30
# 38/38 [==============================] - 4s 107ms/step - loss: 1.0303 - accuracy: 0.6841 - val_loss: 4.2157 - val_accuracy: 0.2360
# Epoch 11/30
# 38/38 [==============================] - 4s 109ms/step - loss: 1.0120 - accuracy: 0.6808 - val_loss: 4.4070 - val_accuracy: 0.2565
# Epoch 12/30
# 38/38 [==============================] - 4s 108ms/step - loss: 0.9605 - accuracy: 0.7007 - val_loss: 4.2201 - val_accuracy: 0.2502
# Epoch 13/30
# 38/38 [==============================] - 4s 107ms/step - loss: 0.9261 - accuracy: 0.7082 - val_loss: 4.3086 - val_accuracy: 0.2386
# Epoch 14/30
# 38/38 [==============================] - 4s 107ms/step - loss: 0.9710 - accuracy: 0.6991 - val_loss: 4.0900 - val_accuracy: 0.2458
# Epoch 15/30
# 38/38 [==============================] - 4s 108ms/step - loss: 0.9241 - accuracy: 0.7132 - val_loss: 4.1780 - val_accuracy: 0.2360
# Epoch 16/30
# 38/38 [==============================] - 4s 107ms/step - loss: 0.9178 - accuracy: 0.7174 - val_loss: 4.2134 - val_accuracy: 0.2663
# Epoch 17/30
# 38/38 [==============================] - 4s 107ms/step - loss: 0.8666 - accuracy: 0.7290 - val_loss: 3.5948 - val_accuracy: 0.4675
# Epoch 18/30
# 38/38 [==============================] - 4s 107ms/step - loss: 0.9058 - accuracy: 0.7049 - val_loss: 4.5569 - val_accuracy: 0.2556
# Epoch 19/30
# 38/38 [==============================] - 4s 108ms/step - loss: 0.8530 - accuracy: 0.7265 - val_loss: 4.4971 - val_accuracy: 0.2609
# Epoch 20/30
# 38/38 [==============================] - 4s 107ms/step - loss: 0.8495 - accuracy: 0.7290 - val_loss: 5.0248 - val_accuracy: 0.2565
# Epoch 21/30
# 38/38 [==============================] - 4s 110ms/step - loss: 0.8828 - accuracy: 0.7140 - val_loss: 4.7672 - val_accuracy: 0.2547
# Epoch 22/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.8057 - accuracy: 0.7340 - val_loss: 5.4052 - val_accuracy: 0.2636
# Epoch 23/30
# 38/38 [==============================] - 4s 107ms/step - loss: 0.8133 - accuracy: 0.7448 - val_loss: 5.2492 - val_accuracy: 0.2841
# Epoch 24/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.9095 - accuracy: 0.7099 - val_loss: 6.7429 - val_accuracy: 0.2458
# Epoch 25/30
# 38/38 [==============================] - 4s 110ms/step - loss: 0.7454 - accuracy: 0.7639 - val_loss: 6.9681 - val_accuracy: 0.2547
# Epoch 26/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.9042 - accuracy: 0.7182 - val_loss: 6.3249 - val_accuracy: 0.2565
# Epoch 27/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.8104 - accuracy: 0.7448 - val_loss: 5.8649 - val_accuracy: 0.2850
# Epoch 28/30
# 38/38 [==============================] - 4s 108ms/step - loss: 0.8057 - accuracy: 0.7382 - val_loss: 5.5175 - val_accuracy: 0.2645
# Epoch 29/30
# 38/38 [==============================] - 4s 106ms/step - loss: 0.8149 - accuracy: 0.7747 - val_loss: 6.7423 - val_accuracy: 0.2582
# Epoch 30/30
# 38/38 [==============================] - 4s 108ms/step - loss: 0.7974 - accuracy: 0.7556 - val_loss: 7.7104 - val_accuracy: 0.2413

# %% [markdown]
# Now that we have trained the model, we can see it's metrics

# %%
from sklearn.metrics import confusion_matrix

valid_sample_output = model.predict(valid_spectrum_matrix, batch_size=60)
predict_class = np.argmax(valid_sample_output, axis=1)
actual_class = np.argmax(valid_label_matrix, axis=1)
cf_matrix = confusion_matrix(actual_class, predict_class)
# Out:
# 19/19 [==============================] - 0s 18ms/step

# %%
import seaborn as sns
import matplotlib.pyplot as plt

star_class = list(stars_encoding.keys())

sns.set(rc = {'figure.figsize':(15,11)})
ax = sns.heatmap(cf_matrix, annot=True, fmt='.3g', cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Star Class')
ax.set_ylabel('Actual Star Category ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(star_class)
ax.yaxis.set_ticklabels(star_class)

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# This confussion matrix shows that, using our undersampling scheme, the most problematic class turns out to be the WDA class! This may mean, for example, that we should explore a more inteligent undersampling algorithm (intead of random undersampling) so as to preserve the most information possible. Of course, we could also explore any other data augmentation scheme, as well as other models.

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']
 
epochs = range(1, len(loss_values) + 1)
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
#
# Plot the model accuracy vs Epochs
#
ax[0].plot(epochs, accuracy, 'bo', label='Training accuracy')
ax[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
ax[0].set_title('Training & Validation Accuracy', fontsize=16)
ax[0].set_xlabel('Epochs', fontsize=16)
ax[0].set_ylabel('Accuracy', fontsize=16)
ax[0].legend()
#
# Plot the loss vs Epochs
#
ax[1].plot(epochs, loss_values, 'bo', label='Training loss')
ax[1].plot(epochs, val_loss_values, 'b', label='Validation loss')
ax[1].set_title('Training & Validation Loss', fontsize=16)
ax[1].set_xlabel('Epochs', fontsize=16)
ax[1].set_ylabel('Loss', fontsize=16)
ax[1].legend()

# %% [markdown]
# Now, we can see the model is adjusting steadily to the training set, though the loss function has large oscilations. On the other hand, the loss function for the validation set steadily decreases, but the validation set accuracy presents large oscilations, so our model requires more work!

# %% [markdown]
# ## Keras ANN: Oversampling the dataset
#
# Now we will try oversampling the dataset. The strategy here is to oversample the minority classes.

# %%
# you can run pip install imblearn to get the imbalanced learn module.
# Resampling the majority dataset in order to balance the set.

from imblearn.over_sampling import RandomOverSampler
over_sampler = RandomOverSampler(random_state=40, sampling_strategy='minority')
X_over, Y_over = over_sampler.fit_resample(train_spectrum_matrix, train_label_matrix)

# %% [markdown]
# we now proceed to train an ANN with the same parameter as with the undersampled dataset.

# %%
#opt = SGD(lr=0.001)

model = Sequential([Dense(4200, input_dim = 4200, activation='relu', kernel_initializer='uniform'),
                    Dense(32, activation='relu', kernel_initializer='uniform'),
                    Dense(64, activation='relu', kernel_initializer='uniform'),
                    Dense(len(stars_encoding), activation='softmax', kernel_initializer='uniform')])

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
history = model.fit(X_over, Y_over, batch_size=32, epochs=30 , validation_data=(valid_spectrum_matrix, valid_label_matrix))
# Out:
# Epoch 1/30
# 173/173 [==============================] - 16s 89ms/step - loss: 1.5323 - accuracy: 0.7169 - val_loss: 1.3782 - val_accuracy: 0.6625
# Epoch 2/30
# 173/173 [==============================] - 15s 88ms/step - loss: 0.7465 - accuracy: 0.8381 - val_loss: 1.9883 - val_accuracy: 0.7738
# Epoch 3/30
# 173/173 [==============================] - 15s 89ms/step - loss: 0.6640 - accuracy: 0.8392 - val_loss: 0.9716 - val_accuracy: 0.7213
# Epoch 4/30
# 173/173 [==============================] - 15s 87ms/step - loss: 0.3529 - accuracy: 0.8965 - val_loss: 0.9016 - val_accuracy: 0.8281
# Epoch 24/30
# 173/173 [==============================] - 15s 88ms/step - loss: 0.3142 - accuracy: 0.9063 - val_loss: 1.1459 - val_accuracy: 0.8299
# Epoch 25/30
# 173/173 [==============================] - 15s 87ms/step - loss: 0.3003 - accuracy: 0.9116 - val_loss: 1.3246 - val_accuracy: 0.8157
# Epoch 26/30
# 173/173 [==============================] - 15s 89ms/step - loss: 0.2933 - accuracy: 0.9125 - val_loss: 1.3967 - val_accuracy: 0.8370
# Epoch 27/30
# 173/173 [==============================] - 16s 91ms/step - loss: 0.2952 - accuracy: 0.9135 - val_loss: 1.6912 - val_accuracy: 0.8335
# Epoch 28/30
# 173/173 [==============================] - 16s 92ms/step - loss: 0.4025 - accuracy: 0.8996 - val_loss: 2.4511 - val_accuracy: 0.7907
# Epoch 29/30
#  96/173 [===============>..............] - ETA: 6s - loss: 0.3028 - accuracy: 0.9134
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5656/3256470928.py in <module>
#       8 opt = keras.optimizers.Adam(learning_rate=0.001)
#       9 model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# ---> 10 history = model.fit(X_over, Y_over, batch_size=32, epochs=30 , validation_data=(valid_spectrum_matrix, valid_label_matrix))
#
# c:\Users\mafalsa\anaconda3\envs\astro\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\mafalsa\anaconda3\envs\astro\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# c:\Users\mafalsa\anaconda3\envs\astro\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\mafalsa\anaconda3\envs\astro\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\mafalsa\anaconda3\envs\astro\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\mafalsa\anaconda3\envs\astro\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# c:\Users\mafalsa\anaconda3\envs\astro\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\mafalsa\anaconda3\envs\astro\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# c:\Users\mafalsa\anaconda3\envs\astro\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import confusion_matrix

valid_sample_output = model.predict(valid_spectrum_matrix, batch_size=60)
predict_class = np.argmax(valid_sample_output, axis=1)
actual_class = np.argmax(valid_label_matrix, axis=1)
cf_matrix = confusion_matrix(actual_class, predict_class)
# Out:
# 19/19 [==============================] - 0s 18ms/step

# %%
import seaborn as sns
import matplotlib.pyplot as plt

star_class = list(stars_encoding.keys())

sns.set(rc = {'figure.figsize':(15,11)})
ax = sns.heatmap(cf_matrix, annot=True, fmt='.3g', cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Star Class')
ax.set_ylabel('Actual Star Category ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(star_class)
ax.yaxis.set_ticklabels(star_class)

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']
 
epochs = range(1, len(loss_values) + 1)
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
#
# Plot the model accuracy vs Epochs
#
ax[0].plot(epochs, accuracy, 'bo', label='Training accuracy')
ax[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
ax[0].set_title('Training & Validation Accuracy', fontsize=16)
ax[0].set_xlabel('Epochs', fontsize=16)
ax[0].set_ylabel('Accuracy', fontsize=16)
ax[0].legend()
#
# Plot the loss vs Epochs
#
ax[1].plot(epochs, loss_values, 'bo', label='Training loss')
ax[1].plot(epochs, val_loss_values, 'b', label='Validation loss')
ax[1].set_title('Training & Validation Loss', fontsize=16)
ax[1].set_xlabel('Epochs', fontsize=16)
ax[1].set_ylabel('Loss', fontsize=16)
ax[1].legend()

# %% [markdown]
# This model actually seems to do quite good! altough we have not validated it sufficiently yet. For that, K fold cross valiation could be a valuable tool, as we will see... But first, let's implement another model architecture in keras!

# %% [markdown]
# ## 1DCNN using keras!

# %%
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.layers import Flatten

# %%
model = Sequential([Conv1D(filters=128, kernel_size=4, activation='relu', strides=2, input_shape=(X_over.shape[1],1)),
                    MaxPooling1D(pool_size=2),
                    Conv1D(filters=64, kernel_size=4, activation='relu', strides=2),
                    MaxPooling1D(pool_size=2),
                    Conv1D(filters=32, kernel_size=4, activation='relu', strides=2),
                    MaxPooling1D(pool_size=2),
                    Conv1D(filters=16, kernel_size=4, activation='relu', strides=2),
                    MaxPooling1D(pool_size=2),
                    Flatten(),
                    Dense(64, activation='relu', kernel_initializer='uniform'),
                    Dense(32, activation='relu', kernel_initializer='uniform'),
                    Dense(len(stars_encoding), activation='softmax', kernel_initializer='uniform')])

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
history = model.fit(X_over, Y_over, batch_size=32, epochs=100 , validation_data=(valid_spectrum_matrix, valid_label_matrix))
# Out:
# Epoch 1/100
# 173/173 [==============================] - 21s 122ms/step - loss: 1.5155 - accuracy: 0.5607 - val_loss: 1.6507 - val_accuracy: 0.5788
# Epoch 2/100
# 173/173 [==============================] - 22s 128ms/step - loss: 1.0417 - accuracy: 0.7155 - val_loss: 1.2169 - val_accuracy: 0.6153
# Epoch 3/100
# 173/173 [==============================] - 21s 122ms/step - loss: 0.7191 - accuracy: 0.8010 - val_loss: 0.9577 - val_accuracy: 0.7070
# Epoch 4/100
# 173/173 [==============================] - 21s 121ms/step - loss: 0.5820 - accuracy: 0.8345 - val_loss: 0.8247 - val_accuracy: 0.7516
# Epoch 5/100
# 173/173 [==============================] - 20s 118ms/step - loss: 0.5272 - accuracy: 0.8468 - val_loss: 0.8585 - val_accuracy: 0.7480
# Epoch 6/100
actual_class = np.argmax(valid_label_matrix, axis=1)
cf_matrix = confusion_matrix(actual_class, predict_class)
# Out:
# 19/19 [==============================] - 1s 60ms/step

# %%
import seaborn as sns
import matplotlib.pyplot as plt

star_class = list(stars_encoding.keys())

sns.set(rc = {'figure.figsize':(15,11)})
ax = sns.heatmap(cf_matrix, annot=True, fmt='.3g', cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Star Class')
ax.set_ylabel('Actual Star Category ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(star_class)
ax.yaxis.set_ticklabels(star_class)

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']
 
epochs = range(1, len(loss_values) + 1)
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
#
# Plot the model accuracy vs Epochs
#
ax[0].plot(epochs, accuracy, 'bo', label='Training accuracy')
ax[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
ax[0].set_title('Training & Validation Accuracy', fontsize=16)
ax[0].set_xlabel('Epochs', fontsize=16)
ax[0].set_ylabel('Accuracy', fontsize=16)
ax[0].legend()
#
# Plot the loss vs Epochs
#
ax[1].plot(epochs, loss_values, 'bo', label='Training loss')
ax[1].plot(epochs, val_loss_values, 'b', label='Validation loss')
ax[1].set_title('Training & Validation Loss', fontsize=16)
ax[1].set_xlabel('Epochs', fontsize=16)
ax[1].set_ylabel('Loss', fontsize=16)
ax[1].legend()

# %% [markdown]
# By the results, we can see this model has had too much epochs to train, as the validation accuracy has slowly fallen, probably do to overfitting in the taining set. Still, the results seem pretty good for this simple example. Let's try now fitting a model using de undersampled set.

# %%
model = Sequential([Conv1D(filters=128, kernel_size=4, activation='relu', strides=2, input_shape=(X_over.shape[1],1)),
                    MaxPooling1D(pool_size=2),
                    Conv1D(filters=64, kernel_size=4, activation='relu', strides=2),
                    MaxPooling1D(pool_size=2),
                    Conv1D(filters=32, kernel_size=4, activation='relu', strides=2),
                    MaxPooling1D(pool_size=2),
                    Conv1D(filters=16, kernel_size=4, activation='relu', strides=2),
                    MaxPooling1D(pool_size=2),
                    Flatten(),
                    Dense(64, activation='relu', kernel_initializer='uniform'),
                    Dense(32, activation='relu', kernel_initializer='uniform'),
                    Dense(len(stars_encoding), activation='softmax', kernel_initializer='uniform')])

opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
history = model.fit(X_under, Y_under, batch_size=32, epochs=60 , validation_data=(valid_spectrum_matrix, valid_label_matrix))
# Out:
# Epoch 1/60
# 38/38 [==============================] - 7s 169ms/step - loss: 2.2581 - accuracy: 0.2851 - val_loss: 4.4879 - val_accuracy: 0.0988
# Epoch 2/60
# 38/38 [==============================] - 7s 198ms/step - loss: 1.8002 - accuracy: 0.3990 - val_loss: 4.5745 - val_accuracy: 0.1630
# Epoch 3/60
# 38/38 [==============================] - 6s 165ms/step - loss: 1.6890 - accuracy: 0.4555 - val_loss: 3.6694 - val_accuracy: 0.1594
# 38/38 [==============================] - 5s 143ms/step - loss: 0.7352 - accuracy: 0.7747 - val_loss: 2.6350 - val_accuracy: 0.3054
# Epoch 24/60
# 38/38 [==============================] - 5s 142ms/step - loss: 0.7451 - accuracy: 0.7697 - val_loss: 2.9351 - val_accuracy: 0.2671
# Epoch 25/60
# 38/38 [==============================] - 5s 141ms/step - loss: 0.7029 - accuracy: 0.7814 - val_loss: 2.6346 - val_accuracy: 0.2734
# Epoch 26/60
# 38/38 [==============================] - 6s 149ms/step - loss: 0.7257 - accuracy: 0.7789 - val_loss: 2.7502 - val_accuracy: 0.3375
# Epoch 27/60
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6727 - accuracy: 0.7872 - val_loss: 3.6844 - val_accuracy: 0.2671
# Epoch 28/60
# 38/38 [==============================] - 6s 146ms/step - loss: 0.6856 - accuracy: 0.7797 - val_loss: 2.4615 - val_accuracy: 0.2903
# Epoch 29/60
# 38/38 [==============================] - 8s 215ms/step - loss: 0.6449 - accuracy: 0.8005 - val_loss: 2.4419 - val_accuracy: 0.2956
# Epoch 30/60
# 38/38 [==============================] - 6s 165ms/step - loss: 0.6366 - accuracy: 0.7980 - val_loss: 3.0667 - val_accuracy: 0.2734
# Epoch 31/60
# 38/38 [==============================] - 5s 134ms/step - loss: 0.6334 - accuracy: 0.7980 - val_loss: 2.8856 - val_accuracy: 0.2787
# Epoch 32/60
# 38/38 [==============================] - 5s 136ms/step - loss: 0.6466 - accuracy: 0.8005 - val_loss: 2.9283 - val_accuracy: 0.2734
# Epoch 33/60
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6206 - accuracy: 0.8013 - val_loss: 2.6695 - val_accuracy: 0.2698
# Epoch 34/60
# 38/38 [==============================] - 6s 147ms/step - loss: 0.6087 - accuracy: 0.7997 - val_loss: 3.5394 - val_accuracy: 0.2778
# Epoch 35/60
# 38/38 [==============================] - 5s 137ms/step - loss: 0.5993 - accuracy: 0.8038 - val_loss: 2.9190 - val_accuracy: 0.2885
# Epoch 36/60
# 38/38 [==============================] - 5s 145ms/step - loss: 0.5800 - accuracy: 0.8055 - val_loss: 2.9120 - val_accuracy: 0.2725
# Epoch 37/60
# 38/38 [==============================] - 6s 147ms/step - loss: 0.5669 - accuracy: 0.8188 - val_loss: 3.1078 - val_accuracy: 0.3143
# Epoch 38/60
# 38/38 [==============================] - 5s 145ms/step - loss: 0.5646 - accuracy: 0.8246 - val_loss: 3.4076 - val_accuracy: 0.2734
# Epoch 39/60
# 38/38 [==============================] - 6s 146ms/step - loss: 0.5912 - accuracy: 0.8055 - val_loss: 3.3035 - val_accuracy: 0.2743
# Epoch 40/60
# 38/38 [==============================] - 5s 144ms/step - loss: 0.5615 - accuracy: 0.8204 - val_loss: 2.9233 - val_accuracy: 0.2796
# Epoch 41/60
# 38/38 [==============================] - 5s 139ms/step - loss: 0.5353 - accuracy: 0.8221 - val_loss: 3.1825 - val_accuracy: 0.2760
# Epoch 42/60
# 38/38 [==============================] - 5s 144ms/step - loss: 0.5157 - accuracy: 0.8296 - val_loss: 3.3285 - val_accuracy: 0.3366
# Epoch 43/60
# 38/38 [==============================] - 5s 142ms/step - loss: 0.6155 - accuracy: 0.8204 - val_loss: 2.9363 - val_accuracy: 0.2698
# Epoch 44/60
# 38/38 [==============================] - 5s 142ms/step - loss: 0.5267 - accuracy: 0.8329 - val_loss: 3.1446 - val_accuracy: 0.2841
# Epoch 45/60
# 38/38 [==============================] - 5s 139ms/step - loss: 0.5163 - accuracy: 0.8313 - val_loss: 3.5566 - val_accuracy: 0.2823
# Epoch 46/60
# 38/38 [==============================] - 5s 142ms/step - loss: 0.4805 - accuracy: 0.8412 - val_loss: 3.2322 - val_accuracy: 0.2805
# Epoch 47/60
# 38/38 [==============================] - 5s 142ms/step - loss: 0.4688 - accuracy: 0.8462 - val_loss: 3.2488 - val_accuracy: 0.2858
# Epoch 48/60
# 38/38 [==============================] - 5s 140ms/step - loss: 0.4700 - accuracy: 0.8454 - val_loss: 3.5888 - val_accuracy: 0.2707
# Epoch 49/60
# 38/38 [==============================] - 5s 142ms/step - loss: 0.4578 - accuracy: 0.8495 - val_loss: 3.4917 - val_accuracy: 0.3624
# Epoch 50/60
# 38/38 [==============================] - 5s 141ms/step - loss: 0.4590 - accuracy: 0.8512 - val_loss: 3.9884 - val_accuracy: 0.2663
# Epoch 51/60
# 38/38 [==============================] - 5s 140ms/step - loss: 0.4617 - accuracy: 0.8446 - val_loss: 3.0591 - val_accuracy: 0.2894
# Epoch 52/60
# 38/38 [==============================] - 5s 143ms/step - loss: 0.4335 - accuracy: 0.8620 - val_loss: 3.8420 - val_accuracy: 0.2769
# Epoch 53/60
# 38/38 [==============================] - 5s 145ms/step - loss: 0.4352 - accuracy: 0.8520 - val_loss: 3.5942 - val_accuracy: 0.2992
# Epoch 54/60
# 38/38 [==============================] - 5s 143ms/step - loss: 0.5098 - accuracy: 0.8412 - val_loss: 3.3909 - val_accuracy: 0.3241
# Epoch 55/60
# 38/38 [==============================] - 5s 143ms/step - loss: 0.6270 - accuracy: 0.8288 - val_loss: 2.4108 - val_accuracy: 0.4185
# Epoch 56/60
# 38/38 [==============================] - 6s 146ms/step - loss: 0.6966 - accuracy: 0.8263 - val_loss: 2.7547 - val_accuracy: 0.2769
# Epoch 57/60
# 38/38 [==============================] - 5s 143ms/step - loss: 0.5163 - accuracy: 0.8446 - val_loss: 2.7043 - val_accuracy: 0.2885
# Epoch 58/60
# 38/38 [==============================] - 5s 130ms/step - loss: 0.4341 - accuracy: 0.8653 - val_loss: 2.9329 - val_accuracy: 0.2805
# Epoch 59/60
# 38/38 [==============================] - 6s 161ms/step - loss: 0.4297 - accuracy: 0.8703 - val_loss: 2.6161 - val_accuracy: 0.3954
# Epoch 60/60
# 38/38 [==============================] - 7s 188ms/step - loss: 0.4015 - accuracy: 0.8653 - val_loss: 3.2463 - val_accuracy: 0.2974

# %% [markdown]
# Again, the undersampled set seems to be unadecuate for our purposes, which is good information
